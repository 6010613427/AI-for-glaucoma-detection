# %% [markdown]
# # **Mount Drive & Check GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !nvidia-smi
# Out:
# Sat May 15 20:46:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    34W / 250W |    349MiB / 16280MiB |      4%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 
# %matplotlib notebook
import sklearn
import skimage
from sklearn import svm, metrics, datasets
from sklearn.utils import Bunch
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression
from skimage.feature import hog

import os
import pylab
from scipy import ndimage, misc
import cv2
import pickle

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16, DenseNet121
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
dataset_path1 = "/content/drive/MyDrive/AI/Dataset/"
test_path = "/content/drive/MyDrive/AI/Testset/"
labels_dict = {'Glaucoma':0, 'Normal':1, 'Others':2}
number = 120

# %% [markdown]
# # **Function**

# %%
import cv2 as cv
import numpy as ppool
def normallize(img):

  norm = ppool.zeros((800,800))
  final = cv.normalize(img,  norm, 0, 255, cv.NORM_MINMAX)

  return final

# %%
def clahe(img_in):
  lab = cv2.cvtColor(img_in,cv2.COLOR_RGB2LAB)
  L, A, B = cv2.split(lab)
  clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(8,8))
  L2 = clahe.apply(L)
  lab = cv2.merge((L2,A,B))
  im_clahe = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
  return im_clahe

# %%
def get_test():
  test = []
  test_label = []
  tagname_file = os.listdir(test_path)
  for j,tagname in enumerate(tagname_file):
    image_file = os.listdir(test_path +tagname + '/')
    for j,img in enumerate(image_file):
      im = cv2.imread(test_path + tagname + '/' + img)
      im_rgb = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
      im_rgb = np.array(im_rgb)

      # Feature
      im_nor = normallize(im_rgb)
      im_clahe = clahe(im_nor)
      test.append(im_clahe)
      test_label.append(labels_dict[tagname])
  test,test_label = shuffle(test,test_label)
  return test, test_label

# %%
def split_train_val(tagname, i):
  dataset_glaucoma = os.listdir(dataset_path1 + tagname)
  val_index = 4-i
  train = []
  train_label = []
  val = []
  val_label = []
  print(tagname)
  for k in range(0,5):
    if k == val_index :
      image_file = os.listdir(dataset_path1 + tagname + '/' + str(k))
      print(image_file)
      for j,img in enumerate(image_file):
        if j < number :
          im = cv2.imread(dataset_path1 + tagname + '/' + str(k) + '/' + img)
          im_rgb = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
          im_rgb = np.array(im_rgb)
          
          # Feature
          im_nor = normallize(im_rgb)
          im_clahe = clahe(im_nor)
          val.append(im_clahe)
          val_label.append(labels_dict[tagname])
    else:
      image_file = os.listdir(dataset_path1 + tagname + '/' + str(k))
      print(image_file)
      for j,img in enumerate(image_file):
        if j < number :
          im = cv2.imread(dataset_path1 + tagname + '/' + str(k) + '/' + img)
          im_rgb = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
          im_rgb = np.array(im_rgb)

          # Feature
          im_nor = normallize(im_rgb)
          im_clahe = clahe(im_nor)
          train.append(im_clahe)
          train_label.append(labels_dict[tagname])

  return train, train_label, val, val_label

# %%
def shuffle(data, label):
  new_data = []
  new_label = []
  index = [i for i in range(len(data))]
  np.random.shuffle(index)
  for i in range(len(data)):
    new_data.append(data[index[i]])
    new_label.append(label[index[i]])

  new_data = np.array(new_data)
  new_label = np.array(new_label)
  n_classes = 3
  new_label = keras.utils.to_categorical(new_label, n_classes)
  
  return new_data, new_label

# %%
def sum_data(k):
  file_name = os.listdir(dataset_path1)
  train = []
  train_label = []
  val = []
  val_label = []
  for name in file_name:
    print(name)
    train_name, train_name_label, val_name, val_name_label = split_train_val(name, k)
    train.extend(train_name)
    train_label.extend(train_name_label)
    val.extend(val_name)
    val_label.extend(val_name_label)
  return train, train_label, val, val_label

# %%
def extract_features(image):
    fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(1, 1), visualize=True)
    hog_image = hog_image.mean(axis=0)

    return hog_image

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix
def confusion(y_test,pred) :
    label_name = ['Glaucoma', 'Normal', 'Others']
    #Confusion Matrix
    # %matplotlib inline 
    confusion_mat1 = confusion_matrix(y_test.argmax(axis=1), pred.argmax(axis=1))
    print(confusion_mat1)
    sns.heatmap(confusion_mat1,annot=True,linewidths=1, fmt = 'd')
    plt.show()
        
    return confusion_mat1

# %%
def roc(fpr_recv,tpr_recv,acc_recv,num=5) :
    color = ["orange","green","blue","red","purple"]
    for i in range(num):
        fpr_use = fpr_recv[i]
        tpr_use = tpr_recv[i]
        acc_use = acc_recv[i]
        
        plt.plot(fpr_use, tpr_use, color='{}'.format(color[i]), label='AUC Fold %d: %0.4f' %(i,acc_use))
        plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend()
    plt.show()

# %% [markdown]
# # **Model**

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import keras

def densenet_model(X_train_recv, y_train_recv, X_val_recv, y_val_recv, r) :

    INIT_LR = 1e-3 
    EPOCHS = 15
    opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

    densenet_model = DenseNet121(weights="imagenet", 
                             include_top= False,
                             input_tensor=Input(shape=(224, 224,3)))
    
    for layer in densenet_model.layers:
        layer.trainable = False
    
    new_model = densenet_model.output
    new_model = AveragePooling2D(pool_size=(5, 5))(new_model)
    new_model = Flatten(name="flatten")(new_model)
    new_model = Dense(64, activation="relu")(new_model)
    new_model = Dropout(0.4)(new_model)
    new_model = Dense(3, activation="softmax")(new_model)
    model = Model(inputs=densenet_model.input, outputs=new_model)

    model.compile(optimizer='adam', 
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])

    print("Wait for Trainning")
    
    history = model.fit(
        X_train_recv, 
        y_train_recv, 
        batch_size=32,
        verbose=1, 
        epochs=EPOCHS,
        validation_data=(X_val_recv, y_val_recv),
    ) 

    filename = 'model_'+ str(r) +'.h5'
    model.save('/content/drive/MyDrive/AI/Model/' +filename)
    print("Already Saved Model")

    y_pred = model.predict(X_val_recv)

    # %matplotlib inline 
    print("Ja tum confu la na")
    confusion(y_val_recv,y_pred)

    fpr_sav = []
    tpr_sav = []
    acc_sav = []
    for i in range(0,3) :

      fpr, tpr, thresholds = roc_curve(y_val_recv[:,i], y_pred[:,i])
      roc_auc = metrics.auc(fpr, tpr)
      fpr_sav.append(fpr)
      tpr_sav.append(tpr)
      acc_sav.append(roc_auc)

    return fpr_sav, tpr_sav, acc_sav

# %% [markdown]
# # **Train**

# %%
# import image from dataset
fpr_all = []
tpr_all = []
acc_all = []
for i in range(0,5):
  train_data, train_label, val_data, val_label = sum_data(i) 
  print(len(train_data), len(train_label), len(val_data), len(val_label))
  train_data, train_label = shuffle(train_data,train_label)
  val_data, val_label = shuffle(val_data,val_label)
  print(len(train_data), len(train_label), len(val_data), len(val_label))
  print(train_data.shape, train_label.shape, val_data.shape, val_label.shape)
  fpr, tpr, acc = densenet_model(train_data, train_label, val_data, val_label, i)
  fpr_all.append(fpr)
  tpr_all.append(tpr)
  acc_all.append(acc)

fpr_all = np.array(fpr_all)
tpr_all = np.array(tpr_all)
acc_all = np.array(acc_all)

for u in range(3):
  print("Graph Class ", str(u))
  roc(fpr_all[:,u], tpr_all[:,u], acc_all[:,u])
# Out:
# Others
# Others
# ['Others_55.png', 'Others_24.png', 'Others_12.png', 'Others_60.png', 'Others_1.png', 'Others_16.png', 'Others_64.png', 'Others_48.png', 'Others_7.png', 'Others_40.png', 'Others_30.png', 'Others_35.png', 'Others_82.png', 'Others_109.png', 'Others_138.png', 'Others_121.png', 'Others_86.png', 'Others_96.png', 'Others_170.png', 'Others_77.png', 'Others_127.png', 'Others_186.png', 'Others_153.png', 'Others_182.png', 'Others_147.png', 'Others_162.png', 'Others_103.png', 'Others_158.png', 'Others_132.png', 'Others_113.png', 'Others_175.png', 'Others_72.png', 'Others_201.png', 'Others_225.png', 'Others_244.png', 'Others_230.png', 'Others_305.png', 'Others_235.png', 'Others_280.png', 'Others_211.png', 'Others_259.png', 'Others_309.png', 'Others_269.png', 'Others_285.png', 'Others_254.png', 'Others_207.png', 'Others_300.png', 'Others_220.png', 'Others_249.png', 'Others_293.png', 'Others_275.png', 'Others_196.png', 'Others_380.png', 'Others_334.png', 'Others_354.png', 'Others_392.png', 'Others_415.png', 'Others_406.png', 'Others_428.png', 'Others_343.png', 'Others_349.png', 'Others_319.png', 'Others_384.png', 'Others_324.png', 'Others_368.png', 'Others_402.png', 'Others_421.png', 'Others_375.png', 'Others_397.png', 'Others_358.png', 'Others_330.png', 'Others_446.png', 'Others_488.png', 'Others_522.png', 'Others_508.png', 'Others_441.png', 'Others_542.png', 'Others_493.png', 'Others_461.png', 'Others_466.png', 'Others_530.png', 'Others_476.png', 'Others_512.png', 'Others_536.png', 'Others_471.png', 'Others_451.png', 'Others_526.png', 'Others_499.png', 'Others_503.png', 'Others_437.png', 'Others_517.png', 'Others_455.png', 'Others_484.png', 'Others_432.png', 'Others_480.png', 'Others_600.png', 'Others_568.png', 'Others_591.png', 'Others_582.png', 'Others_644.png', 'Others_596.png', 'Others_618.png', 'Others_649.png', 'Others_635.png', 'Others_622.png', 'Others_604.png', 'Others_556.png', 'Others_586.png', 'Others_613.png', 'Others_577.png', 'Others_659.png', 'Others_665.png', 'Others_561.png', 'Others_626.png', 'Others_547.png', 'Others_640.png', 'Others_608.png', 'Others_654.png', 'Others_630.png', 'Others_551.png', 'Others_573.png', 'Others_674.png', 'Others_697.png', 'Others_678.png', 'Others_683.png', 'Others_690.png', 'Others_670.png']
# ['Others_15.png', 'Others_21.png', 'Others_51.png', 'Others_9.png', 'Others_31.png', 'Others_37.png', 'Others_56.png', 'Others_44.png', 'Others_61.png', 'Others_25.png', 'Others_2.png', 'Others_179.png', 'Others_157.png', 'Others_89.png', 'Others_150.png', 'Others_145.png', 'Others_79.png', 'Others_173.png', 'Others_115.png', 'Others_164.png', 'Others_83.png', 'Others_126.png', 'Others_67.png', 'Others_95.png', 'Others_73.png', 'Others_142.png', 'Others_111.png', 'Others_104.png', 'Others_169.png', 'Others_187.png', 'Others_133.png', 'Others_119.png', 'Others_210.png', 'Others_239.png', 'Others_252.png', 'Others_204.png', 'Others_301.png', 'Others_294.png', 'Others_277.png', 'Others_246.png', 'Others_234.png', 'Others_217.png', 'Others_264.png', 'Others_200.png', 'Others_193.png', 'Others_223.png', 'Others_270.png', 'Others_290.png', 'Others_260.png', 'Others_307.png', 'Others_229.png', 'Others_284.png', 'Others_321.png', 'Others_363.png', 'Others_325.png', 'Others_351.png', 'Others_412.png', 'Others_313.png', 'Others_337.png', 'Others_382.png', 'Others_403.png', 'Others_427.png', 'Others_422.png', 'Others_376.png', 'Others_409.png', 'Others_344.png', 'Others_396.png', 'Others_386.png', 'Others_390.png', 'Others_419.png', 'Others_394.png', 'Others_355.png', 'Others_367.png', 'Others_361.png', 'Others_331.png', 'Others_435.png', 'Others_445.png', 'Others_485.png', 'Others_519.png', 'Others_544.png', 'Others_525.png', 'Others_538.png', 'Others_442.png', 'Others_502.png', 'Others_507.png', 'Others_454.png', 'Others_489.png', 'Others_482.png', 'Others_450.png', 'Others_467.png', 'Others_496.png', 'Others_516.png', 'Others_458.png', 'Others_477.png', 'Others_532.png', 'Others_473.png', 'Others_513.png', 'Others_559.png', 'Others_609.png', 'Others_660.png', 'Others_612.png', 'Others_629.png', 'Others_550.png', 'Others_619.png', 'Others_571.png', 'Others_638.png', 'Others_590.png', 'Others_634.png', 'Others_656.png', 'Others_625.png', 'Others_576.png', 'Others_606.png', 'Others_584.png', 'Others_581.png', 'Others_597.png', 'Others_648.png', 'Others_641.png', 'Others_567.png', 'Others_546.png', 'Others_601.png', 'Others_687.png', 'Others_669.png', 'Others_680.png', 'Others_703.png', 'Others_667.png', 'Others_673.png', 'Others_694.png']
# ['Others_34.png', 'Others_14.png', 'Others_11.png', 'Others_19.png', 'Others_43.png', 'Others_41.png', 'Others_47.png', 'Others_54.png', 'Others_27.png', 'Others_8.png', 'Others_32.png', 'Others_58.png', 'Others_161.png', 'Others_90.png', 'Others_94.png', 'Others_154.png', 'Others_112.png', 'Others_66.png', 'Others_185.png', 'Others_105.png', 'Others_165.png', 'Others_117.png', 'Others_76.png', 'Others_85.png', 'Others_69.png', 'Others_135.png', 'Others_130.png', 'Others_167.png', 'Others_81.png', 'Others_156.png', 'Others_183.png', 'Others_144.png', 'Others_74.png', 'Others_108.png', 'Others_125.png', 'Others_120.png', 'Others_172.png', 'Others_148.png', 'Others_273.png', 'Others_241.png', 'Others_308.png', 'Others_221.png', 'Others_258.png', 'Others_238.png', 'Others_232.png', 'Others_303.png', 'Others_198.png', 'Others_263.png', 'Others_189.png', 'Others_250.png', 'Others_281.png', 'Others_289.png', 'Others_228.png', 'Others_203.png', 'Others_298.png', 'Others_266.png', 'Others_213.png', 'Others_276.png', 'Others_224.png', 'Others_195.png', 'Others_370.png', 'Others_320.png', 'Others_350.png', 'Others_345.png', 'Others_338.png', 'Others_353.png', 'Others_311.png', 'Others_316.png', 'Others_388.png', 'Others_328.png', 'Others_379.png', 'Others_408.png', 'Others_424.png', 'Others_391.png', 'Others_340.png', 'Others_400.png', 'Others_383.png', 'Others_398.png', 'Others_359.png', 'Others_418.png', 'Others_518.png', 'Others_464.png', 'Others_509.png', 'Others_527.png', 'Others_504.png', 'Others_486.png', 'Others_475.png', 'Others_452.png', 'Others_537.png', 'Others_429.png', 'Others_472.png', 'Others_443.png', 'Others_481.png', 'Others_438.png', 'Others_468.png', 'Others_495.png', 'Others_434.png', 'Others_521.png', 'Others_511.png', 'Others_548.png', 'Others_651.png', 'Others_603.png', 'Others_569.png', 'Others_583.png', 'Others_552.png', 'Others_621.png', 'Others_614.png', 'Others_607.png', 'Others_563.png', 'Others_633.png', 'Others_598.png', 'Others_643.png', 'Others_610.png', 'Others_558.png', 'Others_653.png', 'Others_594.png', 'Others_592.png', 'Others_631.png', 'Others_639.png', 'Others_662.png', 'Others_572.png', 'Others_681.png', 'Others_677.png', 'Others_702.png', 'Others_675.png', 'Others_686.png', 'Others_692.png']
# ['Others_28.png', 'Others_46.png', 'Others_13.png', 'Others_45.png', 'Others_59.png', 'Others_36.png', 'Others_17.png', 'Others_63.png', 'Others_4.png', 'Others_18.png', 'Others_52.png', 'Others_92.png', 'Others_114.png', 'Others_166.png', 'Others_136.png', 'Others_100.png', 'Others_178.png', 'Others_101.png', 'Others_84.png', 'Others_75.png', 'Others_143.png', 'Others_131.png', 'Others_139.png', 'Others_124.png', 'Others_160.png', 'Others_159.png', 'Others_68.png', 'Others_78.png', 'Others_110.png', 'Others_174.png', 'Others_184.png', 'Others_151.png', 'Others_171.png', 'Others_222.png', 'Others_208.png', 'Others_245.png', 'Others_242.png', 'Others_262.png', 'Others_306.png', 'Others_274.png', 'Others_199.png', 'Others_288.png', 'Others_192.png', 'Others_219.png', 'Others_283.png', 'Others_248.png', 'Others_304.png', 'Others_272.png', 'Others_191.png', 'Others_237.png', 'Others_295.png', 'Others_292.png', 'Others_231.png', 'Others_212.png', 'Others_297.png', 'Others_268.png', 'Others_209.png', 'Others_253.png', 'Others_425.png', 'Others_366.png', 'Others_326.png', 'Others_356.png', 'Others_389.png', 'Others_347.png', 'Others_405.png', 'Others_420.png', 'Others_385.png', 'Others_399.png', 'Others_410.png', 'Others_387.png', 'Others_414.png', 'Others_322.png', 'Others_411.png', 'Others_312.png', 'Others_336.png', 'Others_332.png', 'Others_372.png', 'Others_357.png', 'Others_500.png', 'Others_440.png', 'Others_492.png', 'Others_448.png', 'Others_506.png', 'Others_478.png', 'Others_431.png', 'Others_460.png', 'Others_479.png', 'Others_531.png', 'Others_469.png', 'Others_529.png', 'Others_447.png', 'Others_514.png', 'Others_541.png', 'Others_534.png', 'Others_545.png', 'Others_453.png', 'Others_490.png', 'Others_523.png', 'Others_520.png', 'Others_487.png', 'Others_615.png', 'Others_587.png', 'Others_555.png', 'Others_628.png', 'Others_566.png', 'Others_617.png', 'Others_658.png', 'Others_574.png', 'Others_593.png', 'Others_623.png', 'Others_620.png', 'Others_645.png', 'Others_554.png', 'Others_655.png', 'Others_664.png', 'Others_588.png', 'Others_657.png', 'Others_605.png', 'Others_647.png', 'Others_595.png', 'Others_575.png', 'Others_636.png', 'Others_688.png', 'Others_671.png', 'Others_679.png', 'Others_685.png', 'Others_699.png']
# ['Others_10.png', 'Others_26.png', 'Others_38.png', 'Others_42.png', 'Others_20.png', 'Others_62.png', 'Others_22.png', 'Others_33.png', 'Others_3.png', 'Others_6.png', 'Others_50.png', 'Others_23.png', 'Others_57.png', 'Others_118.png', 'Others_128.png', 'Others_149.png', 'Others_140.png', 'Others_99.png', 'Others_70.png', 'Others_88.png', 'Others_188.png', 'Others_146.png', 'Others_93.png', 'Others_176.png', 'Others_181.png', 'Others_65.png', 'Others_123.png', 'Others_71.png', 'Others_168.png', 'Others_155.png', 'Others_107.png', 'Others_129.png', 'Others_80.png', 'Others_98.png', 'Others_116.png', 'Others_163.png', 'Others_227.png', 'Others_287.png', 'Others_279.png', 'Others_278.png', 'Others_256.png', 'Others_206.png', 'Others_214.png', 'Others_202.png', 'Others_291.png', 'Others_302.png', 'Others_286.png', 'Others_216.png', 'Others_240.png', 'Others_310.png', 'Others_236.png', 'Others_251.png', 'Others_265.png', 'Others_197.png', 'Others_218.png', 'Others_255.png', 'Others_247.png', 'Others_226.png', 'Others_404.png', 'Others_317.png', 'Others_417.png', 'Others_401.png', 'Others_323.png', 'Others_342.png', 'Others_333.png', 'Others_395.png', 'Others_335.png', 'Others_327.png', 'Others_369.png', 'Others_348.png', 'Others_378.png', 'Others_352.png', 'Others_407.png', 'Others_381.png', 'Others_393.png', 'Others_362.png', 'Others_339.png', 'Others_373.png', 'Others_315.png', 'Others_365.png', 'Others_377.png', 'Others_497.png', 'Others_491.png', 'Others_470.png', 'Others_543.png', 'Others_528.png', 'Others_463.png', 'Others_515.png', 'Others_436.png', 'Others_449.png', 'Others_430.png', 'Others_540.png', 'Others_474.png', 'Others_498.png', 'Others_444.png', 'Others_501.png', 'Others_465.png', 'Others_524.png', 'Others_457.png', 'Others_439.png', 'Others_510.png', 'Others_483.png', 'Others_642.png', 'Others_589.png', 'Others_624.png', 'Others_611.png', 'Others_570.png', 'Others_578.png', 'Others_616.png', 'Others_637.png', 'Others_599.png', 'Others_585.png', 'Others_565.png', 'Others_602.png', 'Others_549.png', 'Others_560.png', 'Others_579.png', 'Others_632.png', 'Others_661.png', 'Others_627.png', 'Others_652.png', 'Others_672.png', 'Others_682.png', 'Others_676.png', 'Others_696.png', 'Others_668.png']
# Normal
# Normal
# ['Normal_709.png', 'Normal_724.png', 'Normal_731.png', 'Normal_786.png', 'Normal_755.png', 'Normal_753.png', 'Normal_764.png', 'Normal_740.png', 'Normal_737.png', 'Normal_760.png', 'Normal_718.png', 'Normal_751.png', 'Normal_746.png', 'Normal_772.png', 'Normal_706.png', 'Normal_728.png', 'Normal_730.png', 'Normal_900.png', 'Normal_859.png', 'Normal_816.png', 'Normal_847.png', 'Normal_889.png', 'Normal_872.png', 'Normal_
205.png', 'Normal_1226.png', 'Normal_1181.png', 'Normal_1186.png', 'Normal_1214.png', 'Normal_1162.png', 'Normal_1165.png', 'Normal_1144.png', 'Normal_1146.png', 'Normal_1240.png', 'Normal_1218.png', 'Normal_1241.png', 'Normal_1148.png', 'Normal_1243.png', 'Normal_1177.png', 'Normal_1192.png', 'Normal_1193.png', 'Normal_1227.png', 'Normal_1256.png', 'Normal_1178.png', 'Normal_1201.png', 'Normal_1160.png', 'Normal_1257.png', 'Normal_1263.png', 'Normal_1330.png', 'Normal_1324.png', 'Normal_1342.png', 'Normal_1327.png', 'Normal_1296.png', 'Normal_1323.png', 'Normal_1364.png', 'Normal_1308.png', 'Normal_1341.png', 'Normal_1320.png', 'Normal_1379.png', 'Normal_1290.png', 'Normal_1294.png', 'Normal_1348.png', 'Normal_1302.png', 'Normal_1265.png', 'Normal_1271.png', 'Normal_1369.png', 'Normal_1352.png', 'Normal_1359.png', 'Normal_1275.png', 'Normal_1408.png', 'Normal_1406.png', 'Normal_1416.png', 'Normal_1394.png', 'Normal_1413.png', 'Normal_1391.png', 'Normal_1389.png', 'Normal_1421.png', 'Im019_ACRIMA.jpg', 'Im029_ACRIMA.jpg', 'Im006_ACRIMA.jpg', 'Im038_ACRIMA.jpg', 'Im057_ACRIMA.jpg', 'Im043_ACRIMA.jpg', 'Im063_ACRIMA.jpg', 'Im072_ACRIMA.jpg', 'Im053_ACRIMA.jpg', 'Im082_ACRIMA.jpg', 'Im098_ACRIMA.jpg', 'Im076_ACRIMA.jpg', 'Im107_ACRIMA.jpg', 'Im094_ACRIMA.jpg', 'Im113_ACRIMA.jpg', 'Im129_ACRIMA.jpg', 'Im121_ACRIMA.jpg', 'Im144_ACRIMA.jpg', 'Im171_ACRIMA.jpg', 'Im151_ACRIMA.jpg', 'Im166_ACRIMA.jpg', 'Im158_ACRIMA.jpg', 'Im178_ACRIMA.jpg', 'Im199_ACRIMA.jpg', 'Im188_ACRIMA.jpg', 'Im193_ACRIMA.jpg', 'Im181_ACRIMA.jpg', 'Im184_ACRIMA.jpg', 'Im234_ACRIMA.jpg', 'Im214_ACRIMA.jpg', 'Im231_ACRIMA.jpg', 'Im207_ACRIMA.jpg', 'Im206_ACRIMA.jpg', 'Im241_ACRIMA.jpg', 'Im245_ACRIMA.jpg', 'Im259_ACRIMA.jpg', 'Im255_ACRIMA.jpg', 'Im264_ACRIMA.jpg', 'Im277_ACRIMA.jpg', 'Im274_ACRIMA.jpg', 'Im282_ACRIMA.jpg', 'Im287_ACRIMA.jpg', 'Im269_ACRIMA.jpg', 'Im304_ACRIMA.jpg', 'Im295_ACRIMA.jpg', 'Im296_ACRIMA.jpg', 'Im302_ACRIMA.jpg']
# Gluacoma
# Gluacoma
acoma_2054.png', 'Gluacoma_2013.png', 'Gluacoma_2060.png', 'Gluacoma_2036.png', 'Gluacoma_2010.png', 'Gluacoma_2000.png', 'Gluacoma_1984.png', 'Gluacoma_2004.png', 'Gluacoma_2053.png', 'Gluacoma_1977.png', 'Gluacoma_2098.png', 'Gluacoma_2068.png', 'Gluacoma_2087.png', 'Gluacoma_2046.png', 'Gluacoma_2066.png', 'Gluacoma_2023.png', 'Gluacoma_2024.png', 'Gluacoma_2018.png', 'Gluacoma_2079.png', 'Gluacoma_1993.png', 'Gluacoma_2141.png', 'Gluacoma_2130.png', 'Gluacoma_2101.png', 'Gluacoma_2110.png', 'Gluacoma_2166.png', 'Gluacoma_2134.png', 'Gluacoma_2118.png', 'Gluacoma_2165.png', 'Gluacoma_2146.png', 'Gluacoma_2107.png', 'Gluacoma_2174.png', 'Gluacoma_2121.png', 'Gluacoma_2155.png', 'Gluacoma_2290.png', 'Gluacoma_2200.png', 'Gluacoma_2218.png', 'Gluacoma_2248.png', 'Gluacoma_2285.png', 'Gluacoma_2241.png', 'Gluacoma_2186.png', 'Gluacoma_2209.png', 'Gluacoma_2278.png', 'Gluacoma_2192.png', 'Gluacoma_2181.png', 'Gluacoma_2293.png', 'Gluacoma_2223.png', 'Gluacoma_2245.png', 'Gluacoma_2260.png', 'Gluacoma_2233.png', 'Gluacoma_2195.png', 'Gluacoma_2235.png', 'Gluacoma_2277.png', 'Gluacoma_2270.png', 'Gluacoma_2228.png', 'Gluacoma_2315.png', 'Gluacoma_2305.png', 'Gluacoma_2341.png', 'Gluacoma_2355.png', 'Gluacoma_2332.png', 'Gluacoma_2356.png', 'Gluacoma_2318.png', 'Gluacoma_2325.png', 'Gluacoma_2302.png', 'Gluacoma_2335.png', 'Gluacoma_2344.png', 'Im316_g_ACRIMA.jpg', 'Im331_g_ACRIMA.jpg', 'Im341_g_ACRIMA.jpg', 'Im364_g_ACRIMA.jpg', 'Im373_g_ACRIMA.jpg', 'Im351_g_ACRIMA.jpg', 'Im381_g_ACRIMA.jpg', 'Im411_g_ACRIMA.jpg', 'Im401_g_ACRIMA.jpg', 'Im391_g_ACRIMA.jpg', 'Im443_g_ACRIMA.jpg', 'Im432_g_ACRIMA.jpg', 'Im420_g_ACRIMA.jpg', 'Im456_g_ACRIMA.jpg', 'Im467_g_ACRIMA.jpg', 'Im479_g_ACRIMA.jpg', 'Im497_g_ACRIMA.jpg', 'Im534_g_ACRIMA.jpg', 'Im535_g_ACRIMA.jpg', 'Im543_g_ACRIMA.jpg', 'Im511_g_ACRIMA.jpg', 'Im521_g_ ...
# ['Gluacoma_1473.png', 'Gluacoma_1466.png', 'Gluacoma_1445.png', 'Gluacoma_1488.png', 'Gluacoma_1460.png', 'Gluacoma_1433.png', 'Gluacoma_1481.png', 'Gluacoma_1479.png', 'Gluacoma_1434.png', 'Gluacoma_1454.png', 'Gluacoma_1441.png', 'Gluacoma_1575.png', 'Gluacoma_1527.png', 'Gluacoma_1502.png', 'Gluacoma_1525.png', 'Gluacoma_1593.png', '
_2122.png', 'Gluacoma_2099.png', 'Gluacoma_2113.png', 'Gluacoma_2150.png', 'Gluacoma_2104.png', 'Gluacoma_2105.png', 'Gluacoma_2148.png', 'Gluacoma_2163.png', 'Gluacoma_2238.png', 'Gluacoma_2252.png', 'Gluacoma_2250.png', 'Gluacoma_2188.png', 'Gluacoma_2178.png', 'Gluacoma_2274.png', 'Gluacoma_2182.png', 'Gluacoma_2229.png', 'Gluacoma_2198.png', 'Gluacoma_2214.png', 'Gluacoma_2258.png', 'Gluacoma_2267.png', 'Gluacoma_2297.png', 'Gluacoma_2205.png', 'Gluacoma_2207.png', 'Gluacoma_2286.png', 'Gluacoma_2230.png', 'Gluacoma_2220.png', 'Gluacoma_2289.png', 'Gluacoma_2279.png', 'Gluacoma_2201.png', 'Gluacoma_2243.png', 'Gluacoma_2299.png', 'Gluacoma_2321.png', 'Gluacoma_2310.png', 'Gluacoma_2339.png', 'Gluacoma_2298.png', 'Gluacoma_2358.png', 'Gluacoma_2322.png', 'Gluacoma_2345.png', 'Gluacoma_2346.png', 'Gluacoma_2333.png', 'Gluacoma_2316.png', 'Gluacoma_2338.png', 'Im332_g_ACRIMA.jpg', 'Im345_g_ACRIMA.jpg', 'Im339_g_ACRIMA.jpg', 'Im315_g_ACRIMA.jpg', 'Im314_g_ACRIMA.jpg', 'Im343_g_ACRIMA.jpg', 'Im330_g_ACRIMA.jpg', 'Im329_g_ACRIMA.jpg', 'Im354_g_ACRIMA.jpg', 'Im357_g_ACRIMA.jpg', 'Im379_g_ACRIMA.jpg', 'Im367_g_ACRIMA.jpg', 'Im378_g_ACRIMA.jpg', 'Im366_g_ACRIMA.jpg', 'Im356_g_ACRIMA.jpg', 'Im388_g_ACRIMA.jpg', 'Im413_g_ACRIMA.jpg', 'Im414_g_ACRIMA.jpg', 'Im412_g_ACRIMA.jpg', 'Im390_g_ACRIMA.jpg', 'Im403_g_ACRIMA.jpg', 'Im393_g_ ...
# ['Gluacoma_1438.png', 'Gluacoma_1490.png', 'Gluacoma_1462.png', 'Gluacoma_1442.png', 'Gluacoma_1469.png', 'Gluacoma_1450.png', 'Gluacoma_1452.png', 'Gluacoma_1455.png', 'Gluacoma_1472.png', 'Gluacoma_1489.png', 'Gluacoma_1464.png', 'Gluacoma_1477.png', 'Gluacoma_1470.png', 'Gluacoma_1484.png', 'Gluacoma_1578.png', 'Gluacoma_1572.png', 'Gluacoma_1555.png', 'Gluacoma_1548.png', 'Gluacoma_1583.png', 'Gluacoma_1524.png', 'Gluacoma_1584.png', 'Gluacoma_1536.png', 'Gluacoma_1509.png', 'Gluacoma_1562.png', 'Gluacoma_1598.png', 'Gluacoma_1549.png', 'Gluacoma_1497.png', 'Gluacoma_1519.png', 'Gluacoma_1565.png', 'Gluacoma_1539.png', 'Gluacoma_1590.png', 'Gluacoma_1610.png', 'Gluacoma_1501.png', 'Gluacoma_1526.png', 'Gluacoma_1542.png', 'Gluacoma_1515.png', 'Gluacoma_1703.png', 'Gluacoma_1666.png', 'Gluacoma_1653.png', 'Gluac
.png', 'Gluacoma_2275.png', 'Gluacoma_2215.png', 'Gluacoma_2246.png', 'Gluacoma_2282.png', 'Gluacoma_2203.png', 'Gluacoma_2183.png', 'Gluacoma_2352.png', 'Gluacoma_2323.png', 'Gluacoma_2317.png', 'Gluacoma_2311.png', 'Gluacoma_2329.png', 'Gluacoma_2327.png', 'Gluacoma_2349.png', 'Gluacoma_2306.png', 'Gluacoma_2340.png', 'Gluacoma_2308.png', 'Im323_g_ACRIMA.jpg', 'Im338_g_ACRIMA.jpg', 'Im336_g_ACRIMA.jpg', 'Im346_g_ACRIMA.jpg', 'Im371_g_ACRIMA.jpg', 'Im365_g_ACRIMA.jpg', 'Im374_g_ACRIMA.jpg', 'Im380_g_ACRIMA.jpg', 'Im358_g_ACRIMA.jpg', 'Im348_g_ACRIMA.jpg', 'Im404_g_ACRIMA.jpg', 'Im396_g_ACRIMA.jpg', 'Im394_g_ACRIMA.jpg', 'Im384_g_ACRIMA.jpg', 'Im419_g_ACRIMA.jpg', 'Im427_g_ACRIMA.jpg', 'Im447_g_ACRIMA.jpg', 'Im437_g_ACRIMA.jpg', 'Im445_g_ACRIMA.jpg', 'Im421_g_ACRIMA.jpg', 'Im442_g_ACRIMA.jpg', 'Im474_g_ACRIMA.jpg', 'Im461_g_ACRIMA.jpg', 'Im460_ ...
# 1440 1440 360 360
# 1440 1440 360 360
# (1440, 224, 224, 3) (1440, 3) (360, 224, 224, 3) (360, 3)
# Wait for Trainning
# Epoch 1/15
# 45/45 [==============================] - 9s 99ms/step - loss: 2.1504 - accuracy: 0.5136 - val_loss: 0.4514 - val_accuracy: 0.8194
# Epoch 2/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.5345 - accuracy: 0.7971 - val_loss: 0.3120 - val_accuracy: 0.8806
# Epoch 3/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.3913 - accuracy: 0.8508 - val_loss: 0.2305 - val_accuracy: 0.9278
# Epoch 4/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.3059 - accuracy: 0.8861 - val_loss: 0.2045 - val_accuracy: 0.9306
# Epoch 5/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.3097 - accuracy: 0.8802 - val_loss: 0.1724 - val_accuracy: 0.9417
# Epoch 6/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.2197 - accuracy: 0.9193 - val_loss: 0.1646 - val_accuracy: 0.9472
# Epoch 7/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1982 - accuracy: 0.9436 - val_loss: 0.1378 - val_accuracy: 0.9528
# Epoch 8/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1804 - accuracy: 0.9462 - val_loss: 0.1235 - val_accuracy: 0.9611
# Epoch 9/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1757 - accuracy: 0.9349 - val_loss: 0.1009 - val_accuracy: 0.9694
# Epoch 10/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1312 - accuracy: 0.9488 - val_loss: 0.1015 - val_accuracy: 0.9722
# Epoch 11/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1226 - accuracy: 0.9646 - val_loss: 0.1038 - val_accuracy: 0.9583
# Epoch 12/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1056 - accuracy: 0.9625 - val_loss: 0.1126 - val_accuracy: 0.9750
# Epoch 13/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1012 - accuracy: 0.9668 - val_loss: 0.0843 - val_accuracy: 0.9722
# Epoch 14/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.1047 - accuracy: 0.9640 - val_loss: 0.0715 - val_accuracy: 0.9806
# Epoch 15/15
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0610 - accuracy: 0.9807 - val_loss: 0.0737 - val_accuracy: 0.9778
# Already Saved Model
# Ja tum confu la na
# [[114   1   5]
#  [  0 119   1]
#  [  1   0 119]]
# Graph Class  0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Graph Class  1
# Graph Class  2

# %% [markdown]
# # **Test with test set**

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn import metrics
# Python script for confusion matrix creation. 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
# load the model from disk
filename = "/content/drive/MyDrive/AI/Model/model_1.h5"
X_test, Y_test = get_test()

print(X_test.shape, Y_test.shape)

INIT_LR = 1e-3 
EPOCHS = 15
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

model_load = keras.models.load_model(filename)
model_load.compile(optimizer='adam',
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])
pred_test = model_load.predict(X_test)
score = model_load.evaluate(X_test, Y_test, verbose=0)
print(f"Score: {score[1] * 100}")
# Out:
# (294, 224, 224, 3) (294, 3)
# Score: 74.82993006706238

# %%
#Confusion matrix, Accuracy, sensitivity and specificity
from sklearn.metrics import confusion_matrix
# %matplotlib inline
cm1 = confusion(Y_test,pred_test)
print('Confusion Matrix : \n', cm1)

total = sum(sum(cm1))
#####from confusion matrix calculate accuracy
accuracy0=(cm1[0,0]+cm1[1,1]+cm1[2,2])/total
print ('Accuracy : ', accuracy0)

sensitivity0 = cm1[0,0]/(cm1[0,0]+cm1[1,0]+cm1[2,0])
print('Sensitivity Class 0: ', sensitivity0 )

specificity0 = (cm1[1,1]+cm1[2,2]+cm1[1,2]+cm1[2,1])/(cm1[1,0]+cm1[1,1]+cm1[1,2]+cm1[2,0]+cm1[2,1]+cm1[2,2])
print('Specificity Class 0: ', specificity0)

sensitivity1 = cm1[1,1]/(cm1[1,1]+cm1[0,1]+cm1[2,1])
print('Sensitivity Class 1: ', sensitivity1)

specificity1 = (cm1[0,0]+cm1[0,2]+cm1[2,0]+cm1[2,2])/(cm1[0,0]+cm1[0,2]+cm1[2,0]+cm1[2,2]+cm1[0,1]+cm1[2,1])
print('Specificity Class 1: ', specificity1)

sensitivity2 = cm1[2,2]/(cm1[2,2]+cm1[0,2]+cm1[1,2])
print('Sensitivity Class 2: ', sensitivity2)

specificity2 = (cm1[0,0]+cm1[0,1]+cm1[1,0]+cm1[1,1])/(cm1[0,0]+cm1[0,1]+cm1[1,0]+cm1[1,1]+cm1[2,0]+cm1[2,1])
print('Specificity Class 2: ', specificity2)

print( 'Report : ')
print(classification_report(Y_test.argmax(axis=1), pred_test.argmax(axis=1),digits=4))
# Out:
# [[72 29 24]
#  [ 5 80 14]
#  [ 2  0 68]]
# Confusion Matrix :
#  [[72 29 24]
#  [ 5 80 14]
#  [ 2  0 68]]
# Accuracy :  0.7482993197278912
# Sensitivity Class 0:  0.9113924050632911
# Specificity Class 0:  0.9585798816568047
# Sensitivity Class 1:  0.7339449541284404
# Specificity Class 1:  0.8512820512820513
# Sensitivity Class 2:  0.6415094339622641
# Specificity Class 2:  0.9893617021276596
# Report :
#               precision    recall  f1-score   support
#
#            0     0.9114    0.5760    0.7059       125
#            1     0.7339    0.8081    0.7692        99
#            2     0.6415    0.9714    0.7727        70
#
#     accuracy                         0.7483       294
#    macro avg     0.7623    0.7852    0.7493       294
# weighted avg     0.7874    0.7483    0.7431       294
